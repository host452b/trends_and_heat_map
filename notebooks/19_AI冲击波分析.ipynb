# %% [markdown]
# # AI 冲击波分析
#
# AI Impact Wave Analysis — When will AI significantly impact each occupation?
#
# 评分色阶：红色(低分0) → 黄色(中等5) → 绿色(高分10)
# 口碑方差：绿色(稳定0) → 红色(分化5)
# 趋势：红色(暴跌-5) → 白色(持平0) → 绿色(暴涨+5)

# %% [markdown]
# ## Occupations per AI Timeline Bucket

# %%
# Page 1 of 1 — Timeline Overview
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# <tr><th style="border: 1px solid #ddd; padding: 4px 6px;">ai_timeline</th><th style="border: 1px solid #ddd; padding: 4px 6px;">count</th><th style="border: 1px solid #ddd; padding: 4px 6px;">unique_occupations</th><th style="border: 1px solid #ddd; padding: 4px 6px;">mean_ai_resistance</th><th style="border: 1px solid #ddd; padding: 4px 6px;">mean_composite</th><th style="border: 1px solid #ddd; padding: 4px 6px;">mean_value_added</th></tr>
# <tr><td style="border: 1px solid #ddd; padding: 4px 6px;">2025-2028</td><td style="border: 1px solid #ddd; padding: 4px 6px;">585</td><td style="border: 1px solid #ddd; padding: 4px 6px;">24</td><td style="border: 1px solid #ddd; padding: 4px 6px;">2.39</td><td style="border: 1px solid #ddd; padding: 4px 6px;">5.22</td><td style="border: 1px solid #ddd; padding: 4px 6px;">3.65</td></tr>
# ...

# %% [markdown]
# ### 2025-2028

# %%
# Page 1 of 1 — 2025-2028
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Statistics
# Out:
# Total in 2025-2028: 585 records, 24 unique occupations

# %% [markdown]
# ### 2026-2030

# %%
# Page 1 of 1 — 2026-2030
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Statistics
# Out:
# Total in 2026-2030: 3635 records, 123 unique occupations

# %% [markdown]
# ### 2028-2033

# %%
# Page 1 of 1 — 2028-2033
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Statistics
# Out:
# Total in 2028-2033: 14648 records, 439 unique occupations

# %% [markdown]
# ### 2032-2038

# %%
# Page 1 of 1 — 2032-2038
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Statistics
# Out:
# Total in 2032-2038: 20870 records, 623 unique occupations

# %% [markdown]
# ### 2035+

# %%
# Page 1 of 1 — 2035+
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Statistics
# Out:
# Total in 2035+: 14262 records, 388 unique occupations

# %% [markdown]
# ## AI Vulnerability by Category x Timeline

# %%
# Page 1 of 1 — Category x Timeline
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# <tr><th style="border: 1px solid #ddd; padding: 4px 6px;">major_category</th><th style="border: 1px solid #ddd; padding: 4px 6px;">2025-2028</th><th style="border: 1px solid #ddd; padding: 4px 6px;">2026-2030</th><th style="border: 1px solid #ddd; padding: 4px 6px;">2028-2033</th><th style="border: 1px solid #ddd; padding: 4px 6px;">2032-2038</th><th style="border: 1px solid #ddd; padding: 4px 6px;">2035+</th></tr>
# <tr><td style="border: 1px solid #ddd; padding: 4px 6px;">交通运输与物流</td><td style="border: 1px solid #ddd; padding: 4px 6px;">194</td><td style="border: 1px solid #ddd; padding: 4px 6px;">503</td><td style="border: 1px solid #ddd; padding: 4px 6px;">1203</td><td style="border: 1px solid #ddd; padding: 4px 6px;">1034</td><td style="border: 1px solid #ddd; padding: 4px 6px;">306</td></tr>
# ...
