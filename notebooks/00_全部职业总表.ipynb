# %% [markdown]
# # 全球职业发展指数 — 总表
#
# **Global Career Development Index — Master Table**
#
# 12大类 · 1,200职业 · 45国/地区 · 54,000条记录 · 按综合发展指数降序
#
# 评分色阶：红色(低分) → 黄色(中等) → 绿色(高分)
# 口碑方差：绿色(稳定) → 红色(分化)
#
# > 完整54,000条数据请查看 `data/csv/00_all_occupations.csv`
# > 本notebook展示 **Top 500** + **各大类Top 10**

# %%
# 数据统计
# Out:
# 总记录: 54000 | 职业: 1199 | 国家/地区: 45 | 大类: 12

# %% [markdown]
# ## 综合发展指数 Global Top 500

# %%
# Top 500 — Page 1
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Top 500 — Page 2
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Top 500 — Page 3
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Top 500 — Page 4
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Top 500 — Page 5
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Top 500 — Page 6
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Top 500 — Page 7
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Top 500 — Page 8
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Top 500 — Page 9
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ## 各大类 Top 10

# %% [markdown]
# ### 农业、资源与环境 (AGR)

# %%
# AGR Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 文化、艺术与传媒 (ART)

# %%
# ART Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 教育与学术 (EDU)

# %%
# EDU Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 工程与制造 (ENG)

# %%
# ENG Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 金融与商业 (FIN)

# %%
# FIN Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 公共管理与公务员 (GOV)

# %%
# GOV Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 法律与社会服务 (LAW)

# %%
# LAW Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 医疗与健康 (MED)

# %%
# MED Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 技术工种与手工业 (SKL)

# %%
# SKL Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 服务业与消费 (SVC)

# %%
# SVC Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 信息技术与数字化 (TECH)

# %%
# TECH Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 交通运输与物流 (TRA)

# %%
# TRA Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ## 综合发展指数 Bottom 50

# %%
# Bottom 50
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...
