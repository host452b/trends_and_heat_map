# %% [markdown]
# # 职业生活质量排行
#
# Quality of Life Rankings — Which occupations offer the best work-life balance?
#
# **Note:** Higher burnout score = less burnout (better).
#
# 评分色阶：红色(低分0) → 黄色(中等5) → 绿色(高分10)
# 口碑方差：绿色(稳定0) → 红色(分化5)
# 趋势：红色(暴跌-5) → 白色(持平0) → 绿色(暴涨+5)

# %% [markdown]
# ## Top 50 Most Remote-Friendly

# %%
# Page 1 of 1 — Top 50 Most Remote-Friendly
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# <tr><th style="border: 1px solid #ddd; padding: 4px 6px;">Rank</th><th style="border: 1px solid #ddd; padding: 4px 6px;">职业</th><th style="border: 1px solid #ddd; padding: 4px 6px;">职业(英)</th><th style="border: 1px solid #ddd; padding: 4px 6px;">国家/地区</th><th style="border: 1px solid #ddd; padding: 4px 6px;">大类</th><th style="border: 1px solid #ddd; padding: 4px 6px;">代码</th><th style="border: 1px solid #ddd; padding: 4px 6px;">远程友好</th><th style="border: 1px solid #ddd; padding: 4px 6px;">家庭友好</th><th style="border: 1px solid #ddd; padding: 4px 6px;">倦怠水平</th><th style="border: 1px solid #ddd; padding: 4px 6px;">自由度</th><th style="border: 1px solid #ddd; padding: 4px 6px;">成就感</th><th style="border: 1px solid #ddd; padding: 4px 6px;">附加值</th><th style="border: 1px solid #ddd; padding: 4px 6px;">稳定性</th><th style="border: 1px solid #ddd; padding: 4px 6px;">综合指数</th></tr>
# ...

# %% [markdown]
# ## Top 50 Most Family-Friendly

# %%
# Page 1 of 1 — Top 50 Most Family-Friendly
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# <tr><th style="border: 1px solid #ddd; padding: 4px 6px;">Rank</th><th style="border: 1px solid #ddd; padding: 4px 6px;">职业</th><th style="border: 1px solid #ddd; padding: 4px 6px;">职业(英)</th><th style="border: 1px solid #ddd; padding: 4px 6px;">国家/地区</th><th style="border: 1px solid #ddd; padding: 4px 6px;">大类</th><th style="border: 1px solid #ddd; padding: 4px 6px;">代码</th><th style="border: 1px solid #ddd; padding: 4px 6px;">远程友好</th><th style="border: 1px solid #ddd; padding: 4px 6px;">家庭友好</th><th style="border: 1px solid #ddd; padding: 4px 6px;">倦怠水平</th><th style="border: 1px solid #ddd; padding: 4px 6px;">自由度</th><th style="border: 1px solid #ddd; padding: 4px 6px;">成就感</th><th style="border: 1px solid #ddd; padding: 4px 6px;">附加值</th><th style="border: 1px solid #ddd; padding: 4px 6px;">稳定性</th><th style="border: 1px solid #ddd; padding: 4px 6px;">综合指数</th></tr>
# ...

# %% [markdown]
# ## Top 50 Lowest Burnout (Highest Score = Least Burnout)

# %%
# Page 1 of 1 — Top 50 Lowest Burnout (Highest Score = Least Burnout)
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# <tr><th style="border: 1px solid #ddd; padding: 4px 6px;">Rank</th><th style="border: 1px solid #ddd; padding: 4px 6px;">职业</th><th style="border: 1px solid #ddd; padding: 4px 6px;">职业(英)</th><th style="border: 1px solid #ddd; padding: 4px 6px;">国家/地区</th><th style="border: 1px solid #ddd; padding: 4px 6px;">大类</th><th style="border: 1px solid #ddd; padding: 4px 6px;">代码</th><th style="border: 1px solid #ddd; padding: 4px 6px;">远程友好</th><th style="border: 1px solid #ddd; padding: 4px 6px;">家庭友好</th><th style="border: 1px solid #ddd; padding: 4px 6px;">倦怠水平</th><th style="border: 1px solid #ddd; padding: 4px 6px;">自由度</th><th style="border: 1px solid #ddd; padding: 4px 6px;">成就感</th><th style="border: 1px solid #ddd; padding: 4px 6px;">附加值</th><th style="border: 1px solid #ddd; padding: 4px 6px;">稳定性</th><th style="border: 1px solid #ddd; padding: 4px 6px;">综合指数</th></tr>
# ...

# %% [markdown]
# ## Top 50 Highest Autonomy

# %%
# Page 1 of 1 — Top 50 Highest Autonomy
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# <tr><th style="border: 1px solid #ddd; padding: 4px 6px;">Rank</th><th style="border: 1px solid #ddd; padding: 4px 6px;">职业</th><th style="border: 1px solid #ddd; padding: 4px 6px;">职业(英)</th><th style="border: 1px solid #ddd; padding: 4px 6px;">国家/地区</th><th style="border: 1px solid #ddd; padding: 4px 6px;">大类</th><th style="border: 1px solid #ddd; padding: 4px 6px;">代码</th><th style="border: 1px solid #ddd; padding: 4px 6px;">远程友好</th><th style="border: 1px solid #ddd; padding: 4px 6px;">家庭友好</th><th style="border: 1px solid #ddd; padding: 4px 6px;">倦怠水平</th><th style="border: 1px solid #ddd; padding: 4px 6px;">自由度</th><th style="border: 1px solid #ddd; padding: 4px 6px;">成就感</th><th style="border: 1px solid #ddd; padding: 4px 6px;">附加值</th><th style="border: 1px solid #ddd; padding: 4px 6px;">稳定性</th><th style="border: 1px solid #ddd; padding: 4px 6px;">综合指数</th></tr>
# ...

# %% [markdown]
# ## Top 50 Highest Fulfillment

# %%
# Page 1 of 1 — Top 50 Highest Fulfillment
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# <tr><th style="border: 1px solid #ddd; padding: 4px 6px;">Rank</th><th style="border: 1px solid #ddd; padding: 4px 6px;">职业</th><th style="border: 1px solid #ddd; padding: 4px 6px;">职业(英)</th><th style="border: 1px solid #ddd; padding: 4px 6px;">国家/地区</th><th style="border: 1px solid #ddd; padding: 4px 6px;">大类</th><th style="border: 1px solid #ddd; padding: 4px 6px;">代码</th><th style="border: 1px solid #ddd; padding: 4px 6px;">远程友好</th><th style="border: 1px solid #ddd; padding: 4px 6px;">家庭友好</th><th style="border: 1px solid #ddd; padding: 4px 6px;">倦怠水平</th><th style="border: 1px solid #ddd; padding: 4px 6px;">自由度</th><th style="border: 1px solid #ddd; padding: 4px 6px;">成就感</th><th style="border: 1px solid #ddd; padding: 4px 6px;">附加值</th><th style="border: 1px solid #ddd; padding: 4px 6px;">稳定性</th><th style="border: 1px solid #ddd; padding: 4px 6px;">综合指数</th></tr>
# ...

# %% [markdown]
# ## Dream Jobs Composite
#
# Average of (remote_friendly + family_friendly + burnout + autonomy + fulfillment) / 5.
# The ultimate work-life balance occupations.

# %%
# Page 1 of 1 — Dream Jobs
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# <tr><th style="border: 1px solid #ddd; padding: 4px 6px;">Rank</th><th style="border: 1px solid #ddd; padding: 4px 6px;">职业</th><th style="border: 1px solid #ddd; padding: 4px 6px;">职业(英)</th><th style="border: 1px solid #ddd; padding: 4px 6px;">国家/地区</th><th style="border: 1px solid #ddd; padding: 4px 6px;">大类</th><th style="border: 1px solid #ddd; padding: 4px 6px;">代码</th><th style="border: 1px solid #ddd; padding: 4px 6px;">远程友好</th><th style="border: 1px solid #ddd; padding: 4px 6px;">家庭友好</th><th style="border: 1px solid #ddd; padding: 4px 6px;">倦怠水平</th><th style="border: 1px solid #ddd; padding: 4px 6px;">自由度</th><th style="border: 1px solid #ddd; padding: 4px 6px;">成就感</th><th style="border: 1px solid #ddd; padding: 4px 6px;">dream_score</th><th style="border: 1px solid #ddd; padding: 4px 6px;">附加值</th><th style="border: 1px solid #ddd; padding: 4px 6px;">综合指数</th></tr>
# ...
