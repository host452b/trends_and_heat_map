# %% [markdown]
# # 各国职业结构演变
#
# Country-Level Career Structure Evolution — Which countries are gaining/losing in career development trends?
#
# 评分色阶：红色(低分0) → 黄色(中等5) → 绿色(高分10)
# 口碑方差：绿色(稳定0) → 红色(分化5)
# 趋势：红色(暴跌-5) → 白色(持平0) → 绿色(暴涨+5)

# %% [markdown]
# ## Country Trend Summary

# %%
# Page 1 of 1 — Country Summary
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# <tr><th style="border: 1px solid #ddd; padding: 4px 6px;">iso_code</th><th style="border: 1px solid #ddd; padding: 4px 6px;">country_or_region</th><th style="border: 1px solid #ddd; padding: 4px 6px;">n_occupations</th><th style="border: 1px solid #ddd; padding: 4px 6px;">mean_trend_2000_2026</th><th style="border: 1px solid #ddd; padding: 4px 6px;">median_trend_2000_2026</th><th style="border: 1px solid #ddd; padding: 4px 6px;">mean_trend_5yr</th><th style="border: 1px solid #ddd; padding: 4px 6px;">mean_composite</th><th style="border: 1px solid #ddd; padding: 4px 6px;">mean_ai_resistance</th><th style="border: 1px solid #ddd; padding: 4px 6px;">pct_positive_trend</th><th style="border: 1px solid #ddd; padding: 4px 6px;">pct_negative_trend</th></tr>
# ...

# %% [markdown]
# ## Top 10 Countries with Strongest Positive Trends

# %%
# Page 1 of 1 — Gaining Countries
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# <tr><th style="border: 1px solid #ddd; padding: 4px 6px;">iso_code</th><th style="border: 1px solid #ddd; padding: 4px 6px;">country_or_region</th><th style="border: 1px solid #ddd; padding: 4px 6px;">n_occupations</th><th style="border: 1px solid #ddd; padding: 4px 6px;">mean_trend_2000_2026</th><th style="border: 1px solid #ddd; padding: 4px 6px;">median_trend_2000_2026</th><th style="border: 1px solid #ddd; padding: 4px 6px;">mean_trend_5yr</th><th style="border: 1px solid #ddd; padding: 4px 6px;">mean_composite</th><th style="border: 1px solid #ddd; padding: 4px 6px;">mean_ai_resistance</th><th style="border: 1px solid #ddd; padding: 4px 6px;">pct_positive_trend</th><th style="border: 1px solid #ddd; padding: 4px 6px;">pct_negative_trend</th></tr>
# ...

# %% [markdown]
# ## Top 10 Countries with Weakest / Negative Trends

# %%
# Page 1 of 1 — Losing Countries
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# <tr><th style="border: 1px solid #ddd; padding: 4px 6px;">iso_code</th><th style="border: 1px solid #ddd; padding: 4px 6px;">country_or_region</th><th style="border: 1px solid #ddd; padding: 4px 6px;">n_occupations</th><th style="border: 1px solid #ddd; padding: 4px 6px;">mean_trend_2000_2026</th><th style="border: 1px solid #ddd; padding: 4px 6px;">median_trend_2000_2026</th><th style="border: 1px solid #ddd; padding: 4px 6px;">mean_trend_5yr</th><th style="border: 1px solid #ddd; padding: 4px 6px;">mean_composite</th><th style="border: 1px solid #ddd; padding: 4px 6px;">mean_ai_resistance</th><th style="border: 1px solid #ddd; padding: 4px 6px;">pct_positive_trend</th><th style="border: 1px solid #ddd; padding: 4px 6px;">pct_negative_trend</th></tr>
# ...

# %% [markdown]
# ## Mean Trend 2000-2026 by Country x Category

# %%
# Page 1 of 1 — Country x Category Trend
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# <tr><th style="border: 1px solid #ddd; padding: 4px 6px;">country_or_region</th><th style="border: 1px solid #ddd; padding: 4px 6px;">AGR</th><th style="border: 1px solid #ddd; padding: 4px 6px;">ART</th><th style="border: 1px solid #ddd; padding: 4px 6px;">EDU</th><th style="border: 1px solid #ddd; padding: 4px 6px;">ENG</th><th style="border: 1px solid #ddd; padding: 4px 6px;">FIN</th><th style="border: 1px solid #ddd; padding: 4px 6px;">GOV</th><th style="border: 1px solid #ddd; padding: 4px 6px;">LAW</th><th style="border: 1px solid #ddd; padding: 4px 6px;">MED</th><th style="border: 1px solid #ddd; padding: 4px 6px;">SKL</th><th style="border: 1px solid #ddd; padding: 4px 6px;">SVC</th><th style="border: 1px solid #ddd; padding: 4px 6px;">TECH</th><th style="border: 1px solid #ddd; padding: 4px 6px;">TRA</th></tr>
# ...
