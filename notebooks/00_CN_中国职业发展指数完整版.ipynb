# %% [markdown]
# # 中国职业发展指数完整版 — China Career Development Index (Complete Edition)
#
# 中国1,200个细分职业的完整评分数据，含薪资中位数（人民币）。
#
# Complete scoring data for 1,200 occupations in China, including median salary (RMB).
#
# 评分色阶：红色(低分0) → 黄色(中等5) → 绿色(高分10)
# 口碑方差：绿色(稳定0) → 红色(分化5)
# 趋势：红色(暴跌-5) → 白色(持平0) → 绿色(暴涨+5)

# %%
# Dataset overview
# Out:
# 记录数: 1200
# 国家/地区: 1
# 职业细类: 1199

# %%
# Page 1 of 20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Page 2 of 20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Page 3 of 20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Page 4 of 20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Page 5 of 20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Page 6 of 20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Page 7 of 20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Page 8 of 20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Page 9 of 20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Page 10 of 20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Page 11 of 20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Page 12 of 20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Page 13 of 20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Page 14 of 20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Page 15 of 20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Page 16 of 20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Page 17 of 20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Page 18 of 20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Page 19 of 20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Page 20 of 20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Summary statistics
# Out:
# === Score Summary ===
#        learning_cost  education_req  growth_coeff  career_lifespan  opportunity  market_size  supply_demand  developed_scarcity  value_added  cost_performance  stability   safety  occupational_disease  overtime  burnout  skill_versatility  career_switch  reputation_variance  ai_resistance  social_status  remote_friendly  autonomy  family_friendly  fulfillment  entrepreneurship  gender_equality  age_flexibility  social_interaction  physical_demand  license_barrier  cycle_sensitivity  side_job_compat  intl_mobility  industry_monopoly
# ...
