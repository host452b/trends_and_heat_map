# %% [markdown]
# # 中国职业发展指数 — 完整版
#
# **China Career Development Index — Complete Edition**
#
# 1,200 职业 · 34 维评分 · 中国 vs 全球对比 · 按综合发展指数降序
#
# 色阶：红色(低分) → 黄色(中等) → 绿色(高分)

# %%
# 中国职业概况
# Out:
# 中国职业总数: 1200
# 大类: 12
# 综合指数: 4.06 - 7.33 (均值 5.71)
# 中国高于全球均值的职业: 490 / 1200
# 中国低于全球均值的职业: 657 / 1200

# %% [markdown]
# ## 中国综合发展指数 Top 100

# %%
# Top 100 Page 1
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Top 100 Page 2
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ## 各大类 Top 10 (中国)

# %% [markdown]
# ### 农业、资源与环境 (AGR)

# %%
# AGR Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 文化、艺术与传媒 (ART)

# %%
# ART Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 教育与学术 (EDU)

# %%
# EDU Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 工程与制造 (ENG)

# %%
# ENG Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 金融与商业 (FIN)

# %%
# FIN Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 公共管理与公务员 (GOV)

# %%
# GOV Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 法律与社会服务 (LAW)

# %%
# LAW Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 医疗与健康 (MED)

# %%
# MED Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 技术工种与手工业 (SKL)

# %%
# SKL Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 服务业与消费 (SVC)

# %%
# SVC Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 信息技术与数字化 (TECH)

# %%
# TECH Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ### 交通运输与物流 (TRA)

# %%
# TRA Top 10
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ## 中国 vs 全球对比
#
# **cn_vs_global**: 中国综合指数 - 全球均值（正数=中国优于全球，负数=中国低于全球）

# %% [markdown]
# ### 中国优势最大的20个职业

# %%
# China advantage
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# <tr><th style="border: 1px solid #ddd; padding: 4px 6px;">sub_category</th><th style="border: 1px solid #ddd; padding: 4px 6px;">sub_category_en</th><th style="border: 1px solid #ddd; padding: 4px 6px;">major_code</th><th style="border: 1px solid #ddd; padding: 4px 6px;">cn_composite_index</th><th style="border: 1px solid #ddd; padding: 4px 6px;">composite_global_mean</th><th style="border: 1px solid #ddd; padding: 4px 6px;">cn_vs_global</th><th style="border: 1px solid #ddd; padding: 4px 6px;">best_country</th><th style="border: 1px solid #ddd; padding: 4px 6px;">worst_country</th><th style="border: 1px solid #ddd; padding: 4px 6px;">summary_zh</th></tr>
# ...

# %% [markdown]
# ### 中国劣势最大的20个职业

# %%
# China disadvantage
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# <tr><th style="border: 1px solid #ddd; padding: 4px 6px;">sub_category</th><th style="border: 1px solid #ddd; padding: 4px 6px;">sub_category_en</th><th style="border: 1px solid #ddd; padding: 4px 6px;">major_code</th><th style="border: 1px solid #ddd; padding: 4px 6px;">cn_composite_index</th><th style="border: 1px solid #ddd; padding: 4px 6px;">composite_global_mean</th><th style="border: 1px solid #ddd; padding: 4px 6px;">cn_vs_global</th><th style="border: 1px solid #ddd; padding: 4px 6px;">best_country</th><th style="border: 1px solid #ddd; padding: 4px 6px;">worst_country</th><th style="border: 1px solid #ddd; padding: 4px 6px;">summary_zh</th></tr>
# ...

# %% [markdown]
# ## 中国综合指数 Bottom 50

# %%
# Bottom 50
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ## 中国全部职业完整表 (按综合指数降序)

# %%
# Full Page 1/20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Full Page 2/20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Full Page 3/20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Full Page 4/20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Full Page 5/20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Full Page 6/20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Full Page 7/20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Full Page 8/20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Full Page 9/20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Full Page 10/20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Full Page 11/20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Full Page 12/20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Full Page 13/20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Full Page 14/20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Full Page 15/20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Full Page 16/20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Full Page 17/20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Full Page 18/20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Full Page 19/20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %%
# Full Page 20/20
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...
