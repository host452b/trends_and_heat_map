# %% [markdown]
# # 供需失衡预警
#
# Supply-Demand Imbalance Alert — Identifying extreme shortage and oversupply.
#
# supply_demand: 高分 = 供不应求 (shortage), 低分 = 供过于求 (oversupply)
#
# 评分色阶：红色(低分0) → 黄色(中等5) → 绿色(高分10)
# 口碑方差：绿色(稳定0) → 红色(分化5)
# 趋势：红色(暴跌-5) → 白色(持平0) → 绿色(暴涨+5)

# %% [markdown]
# ## Top 50 Most Severe Shortages (Highest supply_demand)

# %%
# Page 1 of 1 — Shortage
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ## Top 50 Most Severe Oversupply (Lowest supply_demand)

# %%
# Page 1 of 1 — Oversupply
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# ...

# %% [markdown]
# ## By-Country Shortage / Oversupply Summary

# %%
# Page 1 of 1 — Country Supply-Demand
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# <tr><th style="border: 1px solid #ddd; padding: 4px 6px;">iso_code</th><th style="border: 1px solid #ddd; padding: 4px 6px;">country_or_region</th><th style="border: 1px solid #ddd; padding: 4px 6px;">mean_supply_demand</th><th style="border: 1px solid #ddd; padding: 4px 6px;">n_shortage</th><th style="border: 1px solid #ddd; padding: 4px 6px;">n_oversupply</th><th style="border: 1px solid #ddd; padding: 4px 6px;">n_balanced</th><th style="border: 1px solid #ddd; padding: 4px 6px;">mean_scarcity</th></tr>
# ...

# %% [markdown]
# ## By-Category Supply-Demand Summary

# %%
# Page 1 of 1 — Category Supply-Demand
# Out:
# <table style="border-collapse: collapse; font-size: 12px;">
# <tr><th style="border: 1px solid #ddd; padding: 4px 6px;">major_category</th><th style="border: 1px solid #ddd; padding: 4px 6px;">mean_supply_demand</th><th style="border: 1px solid #ddd; padding: 4px 6px;">n_shortage</th><th style="border: 1px solid #ddd; padding: 4px 6px;">n_oversupply</th></tr>
# <tr><td style="border: 1px solid #ddd; padding: 4px 6px;">医疗与健康</td><td style="border: 1px solid #ddd; padding: 4px 6px;">7.04</td><td style="border: 1px solid #ddd; padding: 4px 6px;">3012</td><td style="border: 1px solid #ddd; padding: 4px 6px;">7</td></tr>
# <tr><td style="border: 1px solid #ddd; padding: 4px 6px;">信息技术与数字化</td><td style="border: 1px solid #ddd; padding: 4px 6px;">6.82</td><td style="border: 1px solid #ddd; padding: 4px 6px;">982</td><td style="border: 1px solid #ddd; padding: 4px 6px;">13</td></tr>
# ...
